# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# **Objectives:**
#
# * List popular languages for Data Science
# * List commonly libraries used by Data Scientist
# * Show a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. Julia
# 4. JavaScript
# 5. Scala
# 6. Java

# %% [markdown]
# Some of the commonly libraries used by Data Scientists include:
#
# 1. pandas: to manipulate structured (tabular) data.
# 2. numpy: to work with mathematics, matrices and multidimensional arrays.
# 3. sklearn: to train and use Machine Learning models.
# 4. matplotlib: to create data visualizations in Python.
# 5. ggplot: to create data visualizations in R.
# 6. tensorflow: to work with Deep Learning models.
# 7. dplyr: for data manipulation and transformation in R.

# %% [markdown]
# | Data Science Tools |
# |:------------------:|
# | VS Code            |
# | Google Colab       |
# | Spyder             |
# | R Studio           |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4)+5 # This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %%
200/60 # This will convert 200 minutes to hours by diving by 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Omar Fernández
